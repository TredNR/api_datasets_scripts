# %%
import pandas as pd

# %%
who = pd.read_csv('WHO-COVID-19-global-data.csv.CSV')
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
who[:5]
# Out:
#   Date_reported Country_code      Country WHO_region  New_cases  Cumulative_cases  New_deaths  Cumulative_deaths
# 0    2020-01-03           AF  Afghanistan       EMRO          0                 0           0                  0
# 1    2020-01-04           AF  Afghanistan       EMRO          0                 0           0                  0
# 2    2020-01-05           AF  Afghanistan       EMRO          0                 0           0                  0
# 3    2020-01-06           AF  Afghanistan       EMRO          0                 0           0                  0
# 4    2020-01-07           AF  Afghanistan       EMRO          0                 0           0                  0

# %%
russia = who[who['Country'] == 'Russian Federation']
russia[:20]
# Out:
#       Date_reported Country_code             Country WHO_region  New_cases  Cumulative_cases  New_deaths  Cumulative_deaths
# 57140    2020-01-03           RU  Russian Federation       EURO          0                 0           0                  0
# 57141    2020-01-04           RU  Russian Federation       EURO          0                 0           0                  0
# 57142    2020-01-05           RU  Russian Federation       EURO          0                 0           0                  0
# 57143    2020-01-06           RU  Russian Federation       EURO          0                 0           0                  0
# 57144    2020-01-07           RU  Russian Federation       EURO          0                 0           0                  0
# 57145    2020-01-08           RU  Russian Federation       EURO          0                 0           0                  0
# ...

# %%
col_dict = {'date':'Date_report', 'country':'Country', 'region_code':'Country_code', 'who_region':'WHO_region','confirmed':'Cumulative_cases', 'deaths':'Cumulative_deaths', 'new_confirmed':'New_cases', 'new_deaths':'New_deaths'}
import json
with open('WHO_columns_DS_N00001410.json', 'w') as sf:
    json.dump(col_dict, sf)
